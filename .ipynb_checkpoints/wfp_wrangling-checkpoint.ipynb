# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
import json
import requests
import timeit

# %% [markdown]
# ## 1 Read in data
# ### 1.1 Make API request for WFP Data

# %%
small_url = "https://data.humdata.org/api/action/datastore_search?resource_id=12d7c8e3-eff9-4db0-93b7-726825c4fe9a&limit=1"
small_r = requests.get(small_url)
num_records = small_r.json()['result']['total']

url = "https://data.humdata.org/api/action/datastore_search?resource_id=12d7c8e3-eff9-4db0-93b7-726825c4fe9a&limit=" + str(num_records)
r = requests.get(url)
wfp_df = pd.DataFrame(r.json()['result']['records'])

# %% [markdown]
# ### 1.2. Limit data to countries of interest, remove and rename columns

# %%
gdf = gpd.read_file("regions.geojson")
countries = gdf['ADMIN0'].value_counts().index.tolist()
wfp_df = wfp_df[wfp_df['adm0_name'].isin(countries)]

cols = [c for c in wfp_df.columns if c.lower()[-3:] != '_id']
wfp_df = wfp_df[cols].drop(columns=['mp_commoditysource'])
wfp_df = wfp_df.rename(columns={
    "adm0_name": "ADMIN0", 
    "adm1_name": "ADMIN1",
    "cm_name": "commodity",
    "cur_name": "currency",
    "pt_name": "mkt_type",
    "um_name": "unit_measure",
    "mp_month": "month",
    "mp_year": "year",
    "mp_price": "price"
})

# %% [markdown]
# ## 2. Clean data
# ### 2.1 Commodity names, units of measurement
# All commodity names include whether the price is retail or wholesale, but this information is already available in the mkt_type column. Clean commodity names to remove unnecessary information, see which crops are most prominent.

# %%
wfp_df.commodity = wfp_df.commodity.str.split(" - ", expand = True)[0]

# %%
wfp_df.unit_measure.value_counts()
# Out:
# KG           27205
# 100 KG        6182
# 90 KG         5842
# L             5113
# 3.5 KG        5069
# 3 KG          3365
# MT            2379
# USD/LCU       1332
# 50 KG          836
# Head           522
# Unit           446
# Day            181
# 500 ML         169
# 400 G          169
# LCU/3.5kg       46
# Name: unit_measure, dtype: int64

# %% [markdown]
# The most common unit of measurement is KG - limit dataset to only include crops which are measured in KG, and change prices to reflect price per KG (instead of price per 100 KG or per 90 KG). Include the MT unit of measurement since it is a metric ton.
#
# Justification to drop other units of measurement:
# * L - used for oil, fuel, milk, and ground nuts (in one case).
# * USD/LCU - exchange rates for Somalia, South Sudan, and Ethiopia. Will reference an external dataset for conversion instead.
# * Head and Unit -  used for livestock
# * Day - used for wages
# * "500 ML" and "400 G" - 169 instances each, used for milk and bread in Nairobi
# * LCU/3.5kg - used for milling cost

# %%
# Remove rows that do not use kilograms
has_kg = wfp_df.unit_measure.str.contains('KG')
is_metric_ton = wfp_df.unit_measure == 'MT'
wfp_df = wfp_df[has_kg | is_metric_ton]

# Convert to price per kilogram
unit_convert = {
    "KG": 1,
    "100 KG": 1./100,
    "90 KG": 1./90,
    "3.5 KG": 1/3.5,
    "3 KG": 1./3,
    "MT": 1./1000,
    "50 KG": 1./50
}

def convert_to_kg(row):
    new_price = row.price * unit_convert[row.unit_measure]
    row["price_per_kg"] = new_price
    return row

wfp_df = wfp_df.apply(convert_to_kg, axis=1).drop(columns=["unit_measure", "price"])
wfp_df.head()
# Out:
#           ADMIN0       ADMIN1     mkt_name commodity currency   mkt_type  \
# 437265  Ethiopia  Addis Ababa  Addis Ababa      Teff      ETB  Wholesale
# 437266  Ethiopia  Addis Ababa  Addis Ababa      Teff      ETB  Wholesale
# 437267  Ethiopia  Addis Ababa  Addis Ababa      Teff      ETB  Wholesale
# 437268  Ethiopia  Addis Ababa  Addis Ababa      Teff      ETB  Wholesale
# 437269  Ethiopia  Addis Ababa  Addis Ababa      Teff      ETB  Wholesale
#
#        month  year  price_per_kg
# 437265    12  2012        13.085
# 437266     1  2013        12.570
# 437267     2  2013        13.000
# 437268     3  2013        12.998
# 437269     4  2013        13.075

# %% [markdown]
# ### 2.2 Standardize prices
# The earliest hunger score data we have is from 2009, but we are going to use 5 year averages to standardize commodity prices - so we need data from 2004 onwards.
#
# Creating a column to denote time as year + percentage of year elapsed (based on month) for easier filtering.

# %%
wfp_df = wfp_df[wfp_df.year >= 2004]
wfp_df['years_only'] = wfp_df['year'] + pd.to_numeric(wfp_df['month']) / 13.

# %% [markdown]
# I tried finding packages to convert currencies to USD based off of monthly exchange rates, but the well-supported packages (e.g. forex-python) seem to only have data from Europe/major participants in the foreign exchange market.
#
# The African Development Bank Group (ADBG) publishes monthly Excel spreadsheets with exchange rates for our time period of interest, but it would be pretty time intensive to download, clean, and integrate all of the .xlsx files. https://www.afdb.org/en/documents/financial-information/exchange-rates
#
# Instead, I will calculate the percentage difference from each market's listed monthly price for a commodity and the country-wide average price for the commodity over the most recent 5 years.

# %%
def calculate_percent_diff(row, commodity_df):
    # Don't calculate for prices that were measured before 2009
    percent_diff_from_5yr_avg = np.nan
    if row['year'] > 2009:
        # Select data for the 5 years immediately preceding this recording of market price
        from_prev_5yr = commodity_df[
            (commodity_df['years_only'] < row['years_only']) & (
            commodity_df['years_only'] >= row['years_only'] - 5)]
        # Don't calculate the percentage price difference if there are not over 50 
        # previous data points to average across
        if len(from_prev_5yr) >= 50: 
            avg = from_prev_5yr['price_per_kg'].mean()
            percent_diff_from_5yr_avg = (row['price_per_kg'] - avg) / avg
    row['pd_5yr'] = percent_diff_from_5yr_avg
    return row

def get_perc_diff(commodity_df): 
#     ADMIN0 = commodity_df['ADMIN0'].iloc[0]
#     commodity = commodity_df['commodity'].iloc[0]
#     currency = commodity_df['currency'].iloc[0]
#     mkt_type = commodity_df['mkt_type'].iloc[0]
#     print_str = "Adding percentage differences for {}, {}, {}, {}".format(
#         ADMIN0, commodity, currency, mkt_type)
#     print(print_str)
#     start = timeit.default_timer()
    
    commodity_df = commodity_df.apply(lambda row: calculate_percent_diff(row, commodity_df), axis=1)
    
#     stop = timeit.default_timer()
#     print('Time: ', stop - start, "seconds")
    return commodity_df


criteria = ['ADMIN0', 'commodity', 'currency', 'mkt_type']

wfp_df = wfp_df.groupby(criteria).apply(lambda group: get_perc_diff(group))
# Out:
# Adding percentage differences for Ethiopia, Barley, ETB, Retail
# Time:  0.023946735003846698 seconds
# Adding percentage differences for Ethiopia, Beans (fava, dry), ETB, Retail
# Time:  0.355610598999192 seconds
# Adding percentage differences for Ethiopia, Beans (haricot), ETB, Retail
# Time:  0.011385195997718256 seconds
# Adding percentage differences for Ethiopia, Chickpeas, ETB, Retail
# Time:  0.07592461199965328 seconds
# Adding percentage differences for Ethiopia, Corn Soy Blend (CSB++, food aid), ETB, Retail
# Time:  0.00897021599666914 seconds
# Adding percentage differences for Ethiopia, Lentils, ETB, Retail
# Time:  0.3069558999995934 seconds
# Adding percentage differences for Ethiopia, Maize (white), ETB, Retail
# Time:  3.897431710996898 seconds
# Adding percentage differences for Ethiopia, Maize (white), ETB, Wholesale
# Time:  2.9703082959968015 seconds
# Adding percentage differences for Ethiopia, Pasta, ETB, Retail
# Time:  0.2035087440017378 seconds
# Adding percentage differences for Ethiopia, Peas (green, dry), ETB, Retail
# Time:  0.25835465300042415 seconds
# Adding percentage differences for Ethiopia, Rice (imported), ETB, Retail
# Time:  0.20478072200057795 seconds
# Adding percentage differences for Ethiopia, Sorghum, ETB, Retail
# Time:  2.5003800170015893 seconds
# Adding percentage differences for Ethiopia, Sorghum, ETB, Wholesale
# Time:  0.8391540579978027 seconds
# Adding percentage differences for Ethiopia, Sorghum (red), ETB, Wholesale
# Time:  0.25706164599978365 seconds
# Adding percentage differences for Ethiopia, Sorghum (white), ETB, Wholesale
# Time:  0.619760977999249 seconds
# Adding percentage differences for Ethiopia, Sugar, ETB, Retail
# Time:  0.1979729859958752 seconds
# Adding percentage differences for Ethiopia, Sweet potatoes, ETB, Retail
# Time:  0.012677546998020262 seconds
# Adding percentage differences for Ethiopia, Teff, ETB, Wholesale
# Time:  0.9557549890014343 seconds
# Adding percentage differences for Ethiopia, Wheat, ETB, Retail
# Time:  2.4335849339986453 seconds
# Adding percentage differences for Ethiopia, Wheat, ETB, Wholesale
# Time:  2.826677197997924 seconds
# Adding percentage differences for Ethiopia, Wheat flour, ETB, Retail
# Time:  0.07193348500004504 seconds
# Adding percentage differences for Kenya, Beans, KES, Wholesale
# Time:  1.0186902319983346 seconds
# Adding percentage differences for Kenya, Beans (dry), KES, Retail
# Time:  0.5774219779996201 seconds
# Adding percentage differences for Kenya, Beans (dry), KES, Wholesale
# Time:  1.0726521589967888 seconds
# Adding percentage differences for Kenya, Maize, KES, Wholesale
# Time:  1.145928948004439 seconds
# Adding percentage differences for Kenya, Maize (white), KES, Retail
# Time:  1.4680337320023682 seconds
# Adding percentage differences for Kenya, Maize (white), KES, Wholesale
# Time:  1.0619936830044026 seconds
# Adding percentage differences for Kenya, Potatoes (Irish), KES, Wholesale
# Time:  1.0387280069990084 seconds
# Adding percentage differences for Kenya, Sorghum, KES, Wholesale
# Time:  1.0349264100004802 seconds
# Adding percentage differences for Somalia, Maize (white), SOS, Retail
# Time:  3.336872025000048 seconds
# Adding percentage differences for Somalia, Meat (camel), SOS, Retail
# Time:  0.8937900140008423 seconds
# Adding percentage differences for Somalia, Pasta, SOS, Retail
# Time:  0.9073535729985451 seconds
# Adding percentage differences for Somalia, Rice (imported), SOS, Retail
# Time:  3.441212417994393 seconds
# Adding percentage differences for Somalia, Sorghum, SOS, Retail
# Time:  0.0720327089948114 seconds
# Adding percentage differences for Somalia, Sorghum (red), SOS, Retail
# Time:  2.740040222997777 seconds
# Adding percentage differences for Somalia, Sorghum (white), SOS, Retail
# Time:  1.2707029660014086 seconds
# Adding percentage differences for Somalia, Wheat flour, SOS, Retail
# Time:  0.14242568399640732 seconds
# Adding percentage differences for Somalia, Wheat flour (imported), SOS, Retail
# Time:  1.0618065500020748 seconds
# Adding percentage differences for South Sudan, Beans (red), SSP, Retail
# Time:  1.819446114001039 seconds
# Adding percentage differences for South Sudan, Cassava, SSP, Retail
# Time:  0.2859238400051254 seconds
# Adding percentage differences for South Sudan, Cassava (dry), SSP, Retail
# Time:  0.22967161099950317 seconds
# Adding percentage differences for South Sudan, Groundnuts (shelled), SSP, Retail
# Time:  1.4410415700040176 seconds
# Adding percentage differences for South Sudan, Maize (white), SSP, Retail
# Time:  1.0739627729999484 seconds
# Adding percentage differences for South Sudan, Maize (white), SSP, Wholesale
# Time:  0.08585101199423661 seconds
# Adding percentage differences for South Sudan, Maize meal, SSP, Retail
# Time:  0.21911105699837208 seconds
# Adding percentage differences for South Sudan, Millet (white), SSP, Retail
# Time:  0.6758050849966821 seconds
# Adding percentage differences for South Sudan, Millet (white), SSP, Wholesale
# Time:  0.011999548005405813 seconds
# Adding percentage differences for South Sudan, Milling cost (sorghum), SSP, Retail
# Time:  0.03423439099424286 seconds
# Adding percentage differences for South Sudan, Rice, SSP, Retail
# Time:  0.3773009060023469 seconds
# Adding percentage differences for South Sudan, Salt, SSP, Retail
# Time:  0.21220939299382735 seconds
# Adding percentage differences for South Sudan, Sesame, SSP, Retail
# Time:  1.1064123260002816 seconds
# Adding percentage differences for South Sudan, Sorghum (local), SSP, Retail
# Time:  0.24749472999974387 seconds
# Adding percentage differences for South Sudan, Sorghum (local), SSP, Wholesale
# Time:  0.03750534600112587 seconds
# Adding percentage differences for South Sudan, Sorghum (white, imported), SSP, Retail
# Time:  1.8020717760009575 seconds
# Adding percentage differences for South Sudan, Sorghum (white, imported), SSP, Wholesale
# Time:  0.10307703199941898 seconds
# Adding percentage differences for South Sudan, Sugar (brown, imported), SSP, Retail
# Time:  0.371998281996639 seconds
# Adding percentage differences for South Sudan, Wage (non-qualified labour, non-agricultural), SSP, Retail
# Time:  0.00916554000286851 seconds
# Adding percentage differences for South Sudan, Wheat flour, SSP, Retail
# Time:  1.3099178199991002 seconds
# Adding percentage differences for Sudan, Millet, SDG, Retail
# Time:  2.8945952509966446 seconds
# Adding percentage differences for Sudan, Millet, SDG, Wholesale
# Time:  2.0479170229955344 seconds
# Adding percentage differences for Sudan, Sorghum, SDG, Retail
# Time:  3.0760949150062515 seconds
# Adding percentage differences for Sudan, Sorghum (food aid), SDG, Retail
# Time:  1.2631214069988346 seconds
# Adding percentage differences for Sudan, Sorghum (white), SDG, Wholesale
# Time:  2.1833300799989956 seconds
# Adding percentage differences for Sudan, Wheat, SDG, Retail
# Time:  0.38874656400003005 seconds
# Adding percentage differences for Sudan, Wheat, SDG, Wholesale
# Time:  0.9317466169959516 seconds
# Adding percentage differences for Uganda, Beans, UGX, Retail
# Time:  1.2973063769968576 seconds
# Adding percentage differences for Uganda, Beans, UGX, Wholesale
# Time:  0.4102697429989348 seconds
# Adding percentage differences for Uganda, Cassava flour, UGX, Retail
# Time:  1.4506204720019014 seconds
# Adding percentage differences for Uganda, Cassava flour, UGX, Wholesale
# Time:  0.32825687699369155 seconds
# Adding percentage differences for Uganda, Maize, UGX, Retail
# Time:  0.31126351800048724 seconds
# Adding percentage differences for Uganda, Maize, UGX, Wholesale
# Time:  0.721843377003097 seconds
# Adding percentage differences for Uganda, Maize (white), UGX, Retail
# Time:  1.2562415720021818 seconds
# Adding percentage differences for Uganda, Maize flour, UGX, Retail
# Time:  1.4482437100014067 seconds
# Adding percentage differences for Uganda, Millet, UGX, Retail
# Time:  1.2936411190021317 seconds
# Adding percentage differences for Uganda, Plantains, UGX, Retail
# Time:  0.3545491629993194 seconds
# Adding percentage differences for Uganda, Plantains, UGX, Wholesale
# Time:  0.3506360959945596 seconds
# Adding percentage differences for Uganda, Rice, UGX, Wholesale
# Time:  0.2663325870016706 seconds
# Adding percentage differences for Uganda, Sorghum, UGX, Retail
# Time:  1.4095658930018544 seconds

# %%
# Drop rows for which we did not have enough data to calculate the 
# country-wide 5 year average for that commodity.
wfp_df = wfp_df.dropna()

# %% [markdown]
# ### 2.3 Examine differences in pricing trends for retail vs. wholesale markets
# Wholesale markets overall have much greater stability than retail markets. There also seems to have been some sort of retail price shock in 2018.

# %%
grouped = wfp_df.groupby('mkt_type')
print(grouped.agg({'pd_5yr': ['min', 'max', 'mean', 'var']}))

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))
for (key, ax) in zip(grouped.groups.keys(), axes.flatten()):
    group_df = grouped.get_group(key)
    ax.title.set_text(key)
    group_df.plot(x='year', y='pd_5yr', ax=ax, kind='scatter')
plt.show()
# Out:
#              pd_5yr
#                 min         max      mean       var
# mkt_type
# Retail    -0.960617  226.843953  0.500607  7.255837
# Wholesale -0.682036    4.624060  0.350892  0.257526

# %%
wfp_outliers = wfp_df[wfp_df['pd_5yr'] >= 20]
wfp_outliers
# Out:
# Empty DataFrame
# Columns: [ADMIN0, ADMIN1, mkt_name, commodity, currency, mkt_type, month, year, price_per_kg, years_only, pd_5yr]
# Index: []

# %% [markdown]
# There seems to be something that happened in Ethiopia from June - August of 2018 to cause a large price increase. I am skeptical that these are accurate because the numbers are so round, and the prices for some of these commodities come out to over 70USD/kilogram. I am going to drop these values.

# %%
wfp_df = wfp_df[wfp_df['pd_5yr'] < 20]
grouped = wfp_df.groupby('mkt_type')
print(grouped.agg({'pd_5yr': ['min', 'max', 'mean', 'var']}))

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharey=True)
for (key, ax) in zip(grouped.groups.keys(), axes.flatten()):
    group_df = grouped.get_group(key)
    ax.title.set_text(key)
    group_df.plot(x='year', y='pd_5yr', ax=ax, kind='scatter')
plt.show()
# Out:
#              pd_5yr
#                 min        max      mean       var
# mkt_type
# Retail    -0.960617  15.348883  0.457137  1.026226
# Wholesale -0.682036   4.624060  0.350892  0.257526

# %% [markdown]
# Wholesale prices still remain much more stable than retail prices. It's interesting to note that retail prices grew the most in 2016-2017, but wholesale prices grew the least during this same time period. I think we need to consider the difference in price stability, and either have two separate models for wholesale/retail prices, or just limit the scope of our pricing data to just retail prices.

# %% [markdown]
# ### 2.4 Determine approach to different commodities
# * Is there enough data for a certain commodity within each of the admin zones to drop other commodities?
# * What pricing differences are there between different commodities? Can commodities be grouped?
#
# We have:
# - maize products
# - sorghum products
# - wheat
# - millet
# - rice
# - beans
# - cassava products
# - ground nuts
# - potatoes
# - teff
# - pasta
# - sesame
# - plaintains
# - lentils

# %%
commodity_groups = ['Maize', 'Sorghum', 'Wheat', 'Millet', 'Rice', 
                    'Beans', 'Cassava', 'Groundnuts', 'Potatoes', 'Teff',
                    'Pasta', 'Sesame']



# wfp_df.loc[:, 'commodity_group'] = np.nan
# Out:
#            ADMIN0       ADMIN1     mkt_name    commodity currency   mkt_type  \
# 437265   Ethiopia  Addis Ababa  Addis Ababa         Teff      ETB  Wholesale
# 437266   Ethiopia  Addis Ababa  Addis Ababa         Teff      ETB  Wholesale
# 437267   Ethiopia  Addis Ababa  Addis Ababa         Teff      ETB  Wholesale
# 437268   Ethiopia  Addis Ababa  Addis Ababa         Teff      ETB  Wholesale
# 437269   Ethiopia  Addis Ababa  Addis Ababa         Teff      ETB  Wholesale
# ...           ...          ...          ...          ...      ...        ...
# 1389939    Uganda      Mbarara      Mbarara  Maize flour      UGX     Retail
# 1389940    Uganda      Mbarara      Mbarara  Maize flour      UGX     Retail
# 1389941    Uganda      Mbarara      Mbarara  Maize flour      UGX     Retail
# 1389942    Uganda      Mbarara      Mbarara  Maize flour      UGX     Retail
# 1389943    Uganda      Mbarara      Mbarara  Maize flour      UGX     Retail
#
#         month  year  price_per_kg   years_only    pd_5yr  commodity_group
# 437265     12  2012        13.085  2012.923077  0.506526              100
# 437266      1  2013        12.570  2013.076923  0.426725              100
# 437267      2  2013        13.000  2013.153846  0.455846              100
# 437268      3  2013        12.998  2013.230769  0.436644              100
# 437269      4  2013        13.075  2013.307692  0.428014              100
# ...       ...   ...           ...          ...       ...              ...
# 1389939    10  2019      2350.000  2019.769231  0.172312              100
# 1389940    11  2019      2250.000  2019.846154  0.116743              100
# 1389941    12  2019      2225.000  2019.923077  0.098137              100
# 1389942     1  2020      2300.000  2020.076923  0.130177              100
# 1389943     2  2020      2400.000  2020.153846  0.173005              100
#
# [35739 rows x 12 columns]
